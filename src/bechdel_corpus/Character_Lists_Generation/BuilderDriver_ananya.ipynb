# %%
from BechdelCorpusBuilder import *

# %%
## Edit this path
HOME_DIR = "/Users/ananyaapparaju/Downloads/Block 5/src1/bechdel_corpus/data_formatted/"
# HOME_DIR = "/Users/kmaurinjones/Desktop/bechdel/src/bechdel_corpus/"

# %%
# clear
open('books_processed.txt', 'w').close()
open('data_formatted/characterList1.txt', 'w').close()
open('data_formatted/includedNames1.txt', 'w').close()
open('data_formatted/excludedNames1.txt', 'w').close()

# %%
##Uncomment and run
corpus = BechdelCorpus('books.txt', HOME_DIR)
# Out:
# BEGIN BUILD
#
# Adding Persuasion to corpus
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# 	Persuasion successfully added to corpus
#
#
# BUILD COMPLETE
# WRITING TO FILE
# To access corpus contents, use BechdelCorpusObject.read_corpus()

# %%
# listn = ['Anne Elliot', 'Lady Russell', 'Sir Walter Elliot', 'Elizabeth Elliot',
#     'Mary Elliot', 'Charles Musgrove', 'Mary Musgrove', 'Henrietta Musgrove',
#     'Louisa Musgrove', 'Captain Frederick Wentworth', 'Captain Harville',
#     'Mrs. Harville', 'Captain James Benwick', 'Admiral Croft', 'Mrs. Croft',
#     'Sophia Croft', 'William Elliot', 'Mrs. Smith', 'Mrs. Clay', 'Mr. Shepherd',
#     'Mr. Musgrove', 'Mrs. Musgrove', 'Miss Carteret', 'Mr. Hayter',
#     'Mrs. Rooke', 'Mrs. Wallis', 'Mrs. Rooke', 'Miss Musgrove', 'Miss Hayter',
#     'Mrs. Harville Sr.', 'Lady Dalrymple', 'Miss Carteret', 'Mr. Elliot Sr.',
#     'Mrs. Clay Sr.', 'Mrs. Smith Sr.', 'Mr. Smith', 'Mr. Perry', 'Mrs. Rooke Sr.',
#     'Mrs. Bragg', 'Mrs. Molyneux', 'Mrs. Whitworth', 'Mrs. Clay Jr.', 'Mrs. Forster',
#     'Mrs. Poole', 'Miss Bridges', 'Mr. Musgrove Sr.', 'Mrs. Musgrove Sr.',
#     'Mr. Wallis', 'Mr. Hobbins', 'Mrs. Hobbins', 'Captain Walker', 'Mrs. Walker',
#     'Mrs. Johnson', 'Mrs. James', 'Miss Aikin', 'Mrs. Speed', 'Mrs. Whitaker',
#     'Mrs. Beaufort', 'Mrs. Fowle', 'Mrs. Rendell', 'Mrs. Burke', 'Mrs. Bricksome',
#     'Miss Davis', 'Mrs. Cutler', 'Mrs. Cox', 'Mrs. Haggistoun', 'Miss Clewes',
#     'Mrs. Pinkney', 'Mrs. Harvill', 'Mrs. Strood', 'Miss Winton', 'Miss Fanshawe',
#     'Mrs. Wallis Sr.', 'Miss Webbe', 'Miss Miriam Shepherd', 'Miss Carteret',
#     'Miss Louisa Carteret', 'Mrs. Rooke Jr.', 'Mrs. Wilson', 'Mr. Rooke', 'Mr. Musgrove Jr.',
#     'Miss Caroline Shepherd', 'Mr. Hargrove', 'Miss Delancey', 'Miss Lydia Markham',
#     'Miss Mapleton', 'Miss Sneyd', 'Mrs. Frazer', 'Mrs. Dundas', 'Mrs. Smith',
#     'Mrs. Fanny Palmer', 'Miss Lambe', 'Miss Edwards', 'Mrs. William Elliot',
#     'Mrs. Hailes', 'Miss Larkins']

# chars = ['Lady Alicia', 'Miss Atkinson', 'Admiral Baldwin', 'James BENWICK', 'Admiral Brand', 
#          'Captain Brigden', 'Mrs. CLAY', 'Admiral CROFT', 'Dowager Viscountess DALRYMPLE', 
#          'Miss Carteret', 'Sir Archibald Drew', 'the little Durands', 'Sir Walter ELLIOT', 
#          'William Walter Elliot', 'Mrs. Frankland', 'Lady Mary Grierson', 'Captain HARVILLE', 
#          'Fanny HARVILLE', 'HAYTER, Esq.', 'Rev. Charles Hayter', 'Jemima', 'Mackenzie', 
#          'Lady Mary Maclean', 'Mary', 'Sir Basil Morley', 'Charles MUSGROVE', 'Mrs. Charles MUSGROVE', 
#          'Charles MUSGROVE, Esq.', 'Mary Elliot', 'the Pooles', 'Mr. Robinson', 'nurse Rooke', 
#          'Sir Henry RUSSELL', 'Lady Russell', 'Lord St. Ives', 'Sarah', 'John Shepherd', 
#          'Rev. Dr. Shirley', 'Charles SMITH', 'Mrs. Speed', 'the Spicers', 'Stephen', 'Governor Trent', 
#          'Colonel and Mrs. Wallis', 'Sophia WENTWORTH', 'Edward WENTWORTH', 'Frederick WENTWORTH', 'Anne Elliot']

# titles = ['Mrs.', 'Mama', 'Lord', 'Ma', 'Pope', 'Mrs', 'Ms', 'Ms.', 'Lady', 'Sir', 'Miss', 'Mr.', 'Mr', 'Miss'
#               'Colonel', 'Mistress', 'Madam', 'Master', 'Captain', 'Admiral', 'Governor', 'Dr.', 'Dr', 'Captains',
#               'Viscountess', 'Viscount', 'Sir', 'Rev.']


# new = [item.split(" ") for item in listn]
# new = [item for sublist in new for item in sublist]
# new = [item for item in new if item not in titles]
# new = [item.title() for item in new]
# chars = [item.title() for item in chars]
# new = set(new)
# setidf = new.difference(set(chars))
# character_list = setidf.union(new)
# character_list

# %%
names_set = set()
excluded = set()

# names that are incorrectly appearing in `excluded` (and should instead be added to `names_set`)
# unique = ["Governor", "Harville", "Musgrove", "Louisa"]

# things that are incorrectly appearing in `names_set` (and should instead be added to `excluded`)
# unique_exclude = [
#     "Gay Street", "Fortune", "Hall", "Kellynch", "Poor", "West", "Winthrop", "Marys", "Laura",
#     "Place", "Cobb", "August", "June", "Bride", "Pump Yard", "South Park", "Temple", "Thornberry Park",
#     "Tuesday", "Tunbridge Wells", "Don", "Happy", "Marys", "Bishop"
#     ]

with open('data_formatted/characterList1.txt') as f:
    chars = ['Aikin', 'Anne', 'Beaufort', 'Benwick', 'Bragg', 'Bricksome', 'Bridges', 
             'Burke', 'Caroline', 'Carteret', 'Charles', 'Clay', 'Clewes', 'Cox', 'Croft', 
             'Cutler', 'Dalrymple', 'Davis', 'Delancey', 'Dundas', 'Edwards', 'Elizabeth', 'Elliot', 
             'Fanny', 'Fanshawe', 'Forster', 'Fowle', 'Frazer', 'Frederick', 'Haggistoun', 'Hailes', 
             'Hargrove', 'Harvill', 'Harville', 'Hayter', 'Henrietta', 'Hobbins', 'James', 'Johnson', 
             'Lambe', 'Larkins', 'Louisa', 'Lydia', 'Mapleton', 'Markham', 'Mary', 'Miriam', 'Molyneux', 
             'Musgrove', 'Palmer', 'Perry', 'Pinkney', 'Poole', 'Rendell', 'Rooke', 'Russell', 'Shepherd', 
             'Smith', 'Sneyd', 'Sophia', 'Speed', 'Strood', 'Walker', 'Wallis', 'Walter', 'Webbe', 
             'Wentworth', 'Whitaker', 'Whitworth', 'William', 'Wilson', 'Winton', 'Emma', 'Richard', 
             'Baldwin', 'Edward', 'Henry', 'Jemima', 'Penelope', 'Dick', 'Mackenzie', 'Hamilton']

    titles = ['Mrs.', 'Mama', 'Lord', 'Ma', 'Pope', 'Mrs', 'Ms', 'Ms.', 'Lady', 'Sir', 'Miss', 'Mr.', 'Mr', 'Miss'
              'Colonel', 'Mistress', 'Madam', 'Master', 'Captain', 'Admiral', 'Governor', 'Dr.', 'Dr', 'Captains',
              'Viscountess', 'Viscount', 'Sir', 'Rev.', 'Jr.', 'Sr.', 'Bishop', 'Baronet']
    
    for name in f.readlines():
        flag=True
        split_name = name.replace("-", " ").split()
        for sec in split_name:
            sec = sec.strip()
            # if sec in unique_exclude:
            #     continue
            if sec in chars:
                names_set.add(name)
                flag=False
                break
            # elif sec in names.words("female.txt") or sec in names.words("male.txt"):
            #     names_set.add(name)
            #     flag=False
            #     break
            elif sec in titles:
                names_set.add(name)
                flag=False
                break
        if flag:
            excluded.add(name)

# %%
names_set
# Out:
# {' —and Henrietta\n',
#  'A Mrs. Smith\n',
#  'Admiral\n',
#  'Admiral Baldwin\n',
#  'Admiral Croft\n',
#  'Admiral Croft ’\n',
#  'Admiral ’\n',
#  'Anne\n',
#  'Anne Elliot\n',
#  'Anne ’\n',
#  'Baldwin\n',
#  'Baldwin ’\n',
#  'Baronet\n',
#  'Benwick\n',
#  'Bishop\n',
#  'Captain\n',
#  'Captain Benwick\n',
#  'Captain Benwick ’\n',
#  'Captain Brigden\n',
#  'Captain Croft\n',
#  'Captain Frederick Wentworth ’\n',
#  'Captain Harville\n',
#  'Captain Harville ’\n',
#  'Captain Wentworth\n',
#  'Captain Wentworth —\n',
#  'Captain Wentworth ’\n',
#  'Captain Wentworth ’ s\n',
#  'Captains Harville\n',
#  'Captains Wentworth\n',
#  'Charles\n',
#  'Charles Hayter\n',
#  'Charles Hayter ’\n',
#  'Charles II\n',
#  'Charles Musgrove\n',
#  'Charles Smith\n',
#  'Charles ’\n',
#  'Charles “\n',
#  'Clay\n',
#  'Colonel Wallis\n',
#  'Colonel Wallis ’\n',
#  'Could Anne\n',
#  'Cousin Charles\n',
#  'Croft\n',
#  'Croft ’\n',
#  'Dalrymple\n',
#  'Dear Miss Elliot\n',
#  'Dick\n',
# ...

# %%
# test_1 = set()

# for name in names_set:
#     name_split = name.split(" ")
#     for item in name_split:
#         if item not in titles:
#             if item.isalpha():
#                 test_1.add(item)
# test_1

# %%
# print(names_set)
names_dict = dict()
tmp_set = names_set.copy()

def add_alias(alias, name, names_dict, tmp_set):
    if name not in names_dict:
        names_dict[name] = list()
    names_dict[name].append(alias)
    tmp_set.remove(alias)

# simple mentions
# all names from names_set
lst = [
 'Mrs. Croft\n',
 'Mrs. Croft ’\n',
 'Mrs. Frankland\n',
 'Mrs. Harville\n',
 'Mrs. Harville ’\n',
 'Mrs. Musgrove\n',
 'Mrs. Musgrove ’\n',
 'Mrs. Shirley\n',
 'Mrs. Smith\n',
 'Mrs. Smith ’\n',
 'Mrs. Wallis\n',
 'Mrs. Wallis ’\n',
 'Charles Musgrove\n',
 'Governor Trent\n',
 'Lady Alicia\n',
 'Lord St. Ives\n',
 'Mackenzie\n',
 'Lady Mary Grierson\n',
 'Old Lady Mary Maclean\n',
 'Miss Atkinson\n',
 'Mr. Robinson\n', 
 'Mr. Robinson ’\n',
 'Jemima\n',
 'Lady Elliot\n',
 'Lady Elliot ’\n',
 'Lord Byron\n',
 'Lord Byron ’\n',
 'Master Harry\n',
 'Miss Hayters\n',
 'Miss Larolles\n',
 'Lady Wentworth\n',
 'Lady Wentworth ’\n',
 'Penelope\n',
 'Emma\n',
 'Edward\n',
 'Edward ’\n',
 'Henry\n',
 'Russell\n',
 'Sir William\n',
 'Mr. Scott\n',
]

for n in lst:
    formatted_n = n.replace("’", "").replace("“","").strip()
    add_alias(n, formatted_n, names_dict, tmp_set)
    
complex_set = tmp_set.copy()

# aliases for names in names_set
for name in complex_set:
        
    if 'Benwick' in name:
        add_alias(name, 'James Benwick', names_dict, tmp_set)
    elif 'Brigden' in name:
        add_alias(name, 'Captain Brigden', names_dict, tmp_set)
    elif 'Croft' in name:
        add_alias(name, 'Captain Croft', names_dict, tmp_set)
    elif 'Captain Wentworth' in name or 'Frederick' in name or 'Captains Wentworth' in name or 'Mr. Wentworth' in name:
        add_alias(name, 'Captain Frederick Wentworth', names_dict, tmp_set)
    elif 'Captain Harville' in name or 'Captains Harville' in name:
        add_alias(name, 'Captain Harville', names_dict, tmp_set)
    elif 'Charles Hayter' in name:
        add_alias(name, 'Charles Hayter', names_dict, tmp_set)
    elif 'Henrietta' in name:
        add_alias(name, 'Henrietta Musgrove', names_dict, tmp_set)
    elif 'Charles Smith' in name or 'Mr. Smith' in name: 
        add_alias(name, 'Charles Smith', names_dict, tmp_set)
    elif 'Clay' in name or 'Penelope' in name:
        add_alias(name, 'Penelope Clay', names_dict, tmp_set)
    elif 'Wallis' in name:
        add_alias(name, 'Colonel Wallis', names_dict, tmp_set)
    elif 'Anne' in name:
        add_alias(name, 'Anne Elliot', names_dict, tmp_set)
    elif 'Louisa' in name:
        add_alias(name, 'Louisa Musgrove', names_dict, tmp_set)
    elif 'Dick' in name:
        add_alias(name, 'Dick Musgrove', names_dict, tmp_set)
    elif 'Elizabeth' in name:
        add_alias(name, 'Elizabeth Elliot', names_dict, tmp_set)
    elif 'Lady Elliot' in name:
        add_alias(name, 'Lady Elliot', names_dict, tmp_set)
    elif 'Shirley' in name:
        add_alias(name, 'Rev. Dr. Shirley', names_dict, tmp_set)
    elif 'Fanny' in name or 'Miss Harville' in name:
        add_alias(name, 'Fanny Harville', names_dict, tmp_set)
    elif 'Miss Carteret' in name:
        add_alias(name, 'Miss Carteret', names_dict, tmp_set)
    elif 'John Shepherd' in name or 'Mr. Shepherd' in name:
        add_alias(name, 'John Shepherd', names_dict, tmp_set)
    elif 'Mrs. Rooke' in name or 'Nurse' in name:
        add_alias(name, 'Nurse Rooke', names_dict, tmp_set)
    elif 'Richard' in name:
        add_alias(name, 'Richard Musgrove', names_dict, tmp_set)
    elif 'Henry Russell' in name:
        add_alias(name, 'Sir Henry Russell', names_dict, tmp_set)
    elif 'Walter' in name:
        add_alias(name, 'Sir Walter Elliot', names_dict, tmp_set)
    elif 'Sophia' in name:
        add_alias(name, 'Sophia Wentworth', names_dict, tmp_set)
    elif 'Lady Russell' in name:
        add_alias(name, 'Lady Russell', names_dict, tmp_set)
    elif 'Baldwin' in name or 'Admiral' in name:
        add_alias(name, 'Admiral Baldwin', names_dict, tmp_set)
    elif 'Dowager Viscountess' in name or 'Lady Dalrymple' in name or 'Viscountess Dalrymple' in name:
        add_alias(name, 'Dowager Viscountess Dalrymple', names_dict, tmp_set)
    elif 'James' in name or 'Stevenson' in name:
        add_alias(name, 'James Stevenson', names_dict, tmp_set)
    elif 'Mrs. Charles' in name:
        add_alias(name, 'Mrs. Charles Musgrove', names_dict, tmp_set)
    elif 'Sir Archibald' in name:
        add_alias(name, 'Sir Archibald Drew', names_dict, tmp_set)
    elif 'Sir Basil' in name:
        add_alias(name, 'Sir Basil Morley', names_dict, tmp_set)
    elif 'Mrs. Musgrove' in name:
        add_alias(name, 'Mrs. Musgrove', names_dict, tmp_set)
    elif 'Mrs. Smith' in name:
        add_alias(name, 'Mrs. Smith', names_dict, tmp_set)
     # ambiguous names
    elif 'Miss Elliot' in name:
        add_alias(name, 'Ambiguous Miss Elliot', names_dict, tmp_set)
    elif 'Miss Harville' in name:
        add_alias(name, 'Ambiguous Miss Harville', names_dict, tmp_set)
    elif 'Miss Musgrove' in name or 'Miss Musgroves' in name:
        add_alias(name, 'Ambiguous Miss Musgrove', names_dict, tmp_set)
    elif 'Mr. Musgrove' in name or 'Mr. Musgroves' in name:
        add_alias(name, 'Ambiguous Mr. Musgrove', names_dict, tmp_set)
    elif 'Mr. Elliot' in name:
        add_alias(name, 'Ambiguous Mr. Elliot', names_dict, tmp_set)
    elif 'Charles' in name:
        add_alias(name, 'Ambiguous Charles', names_dict, tmp_set)
    elif 'Mary' in name:
        add_alias(name, 'Ambiguous Mary', names_dict, tmp_set)
    elif 'Elliot' in name:
        add_alias(name, 'Ambiguous Elliot', names_dict, tmp_set)
    elif 'Harville' in name:
        add_alias(name, 'Ambiguous Harville', names_dict, tmp_set)
    elif 'Musgrove' in name:
        add_alias(name, 'Ambiguous Musgrove', names_dict, tmp_set)
    elif 'Rooke' in name:
        add_alias(name, 'Ambiguous Rooke', names_dict, tmp_set)
    elif 'Hayter' in name:
        add_alias(name, 'Ambiguous Hayter', names_dict, tmp_set)
    elif 'Wentworth' in name:
        add_alias(name, 'Ambiguous Wentworth', names_dict, tmp_set)
    elif 'Dalrymple' in name:
        add_alias(name, 'Ambiguous Dalrymple', names_dict, tmp_set)
    elif 'Shepherd' in name:
        add_alias(name, 'Ambiguous Shepherd', names_dict, tmp_set)
    elif 'Mr.' in name or 'Baronet' in name or 'Dr.' in name or 'Lord' in name or 'Bishop' in name or 'Captain' in name or 'Sir' in name:
        add_alias(name, 'Ambiguous Male', names_dict, tmp_set)
    elif 'Miss' in name or 'Mrs.' in name or 'Mrs' in name:
        add_alias(name, 'Ambiguous Female', names_dict, tmp_set)
    else:
        add_alias(name, 'Ambiguous Male', names_dict, tmp_set)
# names_dict.keys()
tmp_set
# Out:
# set()

# %% [raw]
# # print list to see all names
# # names_dict.keys()
# female_names = ['Miss Morton', 'Miss Sparks', 'Miss Walker', 'Martha Sharpe', 'Miss Careys', 'Miss Godby', 'Mrs. Burgess', 'Mrs. Clarke', 'Mrs. Dennison', 'Mrs. Ellison', 'Mrs. Richardson', 'Mrs. Smith', 'Mrs. Taylor', 'Elinor Dashwood', 'Sophia Grey', 'Mrs. Dashwood', 'Lucy Steele', 'Marianne Dashwood', 'Eliza Williams', 'Ambiguous Miss Dashwood', 'Mary Brown', 'Betty', 'Charlotte Palmer', 'Fanny Dashwood', 'Sally Scott', 'Margaret Dashwood', 'Lady Middleton', 'Mrs. Ferrars', 'Mrs. Jennings', 'Biddy Henshawe', 'Anne Steele', 'Lady Elliott', 'Annamaria', 'Nancy Steele']

# %%
females = ['Anne Elliot', 'Mrs. Croft', 'Mrs. Frankland', 'Mrs. Harville', 'Mrs. Musgrove', 'Mrs. Shirley', 
           'Mrs. Wallis', 'Lady Alicia', 'Lady Mary Grierson', 'Old Lady Mary Maclean', 'Miss Atkinson', 
           'Jemima', 'Lady Elliot', 'Miss Hayters', 'Miss Larolles', 'Lady Wentworth', 'Penelope Clay', 'Emma', 
           'Russell', 'Dowager Viscountess Dalrymple', 'Fanny Harville', 'Lady Russell', 'Nurse Rooke', 
           'Elizabeth Elliot', 'Ambiguous Miss Musgrove', 'Ambiguous Miss Elliot', 'Ambiguous Female', 
           'Louisa Musgrove', 'Ambiguous Mary', 'Sophia Wentworth', 'Mrs. Charles Musgrove', 'Mrs. Smith',
           'Miss Carteret']

males = ['Charles Musgrove', 'Governor Trent', 'Lord St. Ives', 'Mackenzie', 'Mr. Robinson', 
         'Lord Byron', 'Master Harry', 'Sir William', 'Mr. Scott', 'Captain Croft', 'Sir Walter Elliot', 
         'Rev. Dr. Shirley', 'John Shepherd', 'Ambiguous Male', 'Captain Frederick Wentworth', 
         'Ambiguous Rooke', 'Charles Smith', 'Henrietta Musgrove', 'Ambiguous Mr. Musgrove', 
         'Charles Hayter', 'Admiral Baldwin', 'James Benwick', 'Captain Brigden', 'Sir Basil Morley', 
         'Ambiguous Mr. Elliot', 'Colonel Wallis', 'Richard Musgrove', 'Ambiguous Charles', 'Sir Henry Russell',
         'Captain Harville', 'Sir Archibald Drew', 'Dick Musgrove', 'James Stevenson']

# %%
import json
# names_dict
reverse_lookup_dict = dict()
for key, value in names_dict.items():
    for v in value:
        if key in females:
            gender = "Female"
        elif key in males:
            gender = "Male"
        else:
            gender = "Unknown"
        if "\n" in v:
            new_v = " ".join(v.splitlines())
        reverse_lookup_dict[new_v] = (key, gender)

with open('characters/persuasion-characters.txt', 'w') as f:
     f.write(json.dumps(reverse_lookup_dict))

# %%
reverse_lookup_dict
# Out:
# {'Mrs. Croft': ('Mrs. Croft', 'Female'),
#  'Mrs. Croft ’': ('Mrs. Croft', 'Female'),
#  'Mrs. Frankland': ('Mrs. Frankland', 'Female'),
#  'Mrs. Harville': ('Mrs. Harville', 'Female'),
#  'Mrs. Harville ’': ('Mrs. Harville', 'Female'),
#  'Mrs. Musgrove': ('Mrs. Musgrove', 'Female'),
#  'Mrs. Musgrove ’': ('Mrs. Musgrove', 'Female'),
#  '” Mrs. Musgrove': ('Mrs. Musgrove', 'Female'),
#  'Mrs. Shirley': ('Mrs. Shirley', 'Female'),
#  'Mrs. Smith': ('Mrs. Smith', 'Female'),
#  'Mrs. Smith ’': ('Mrs. Smith', 'Female'),
#  'A Mrs. Smith': ('Mrs. Smith', 'Female'),
#  '” Mrs. Smith': ('Mrs. Smith', 'Female'),
#  'Mrs. Wallis': ('Mrs. Wallis', 'Female'),
#  'Mrs. Wallis ’': ('Mrs. Wallis', 'Female'),
#  'Charles Musgrove': ('Charles Musgrove', 'Male'),
#  'Governor Trent': ('Governor Trent', 'Male'),
#  'Lady Alicia': ('Lady Alicia', 'Female'),
#  'Lord St. Ives': ('Lord St. Ives', 'Male'),
#  'Mackenzie': ('Mackenzie', 'Male'),
#  'Lady Mary Grierson': ('Lady Mary Grierson', 'Female'),
# ...

# %%
names_set = set()
with open('data_formatted/excludedNames1.txt') as f:
    for name in f.readlines():
        names_set.add(name.strip())
print(names_set)
# Out:
# set()

# %%
with open('data_formatted/characterList1.txt', 'r+') as f:
    np_set = set()
    all_nps = f.readlines()
    for np in all_nps:
        np_set.add(np.replace("”","").replace("“","").replace("‘","").replace("’","").strip())
    # for np in np_set:
    #     print(np)

# %%
with open("characters/persuasion-characters.txt") as f:
    characters_dict = json.load(f)
