# %%
from BechdelCorpusBuilder import *

# %%
## Edit this path
# HOME_DIR = '/Users/michelleyun/bechdel/src/bechdel_corpus'
HOME_DIR = '/Users/kmaurinjones/Desktop/School/UBC/UBC_Coursework/block_5/cl523/bechdel/src/bechdel_corpus'

# %%
os.mkdir("data_formatted")
Bechdel = BechdelCorpus('books.txt', HOME_DIR)
# Out:
# BEGIN BUILD
#
# Adding Sense and Sensibility to corpus
# sense-and-sensibility_11
# sense-and-sensibility_23
# 	Sense and Sensibility successfully added to corpus
#
#
# Adding Pride and Prejudice to corpus
# 	Pride and Prejudice successfully added to corpus
#
#
# Adding Mansfield Park to corpus
# 	Mansfield Park successfully added to corpus
#
#
# Adding Emma to corpus
# 	Emma successfully added to corpus
#
#
# Adding Northanger Abbey to corpus
# northanger-abbey_1
# 	Northanger Abbey successfully added to corpus
#
#
# Adding Persuasion to corpus
# 	Persuasion successfully added to corpus
#
#
# Adding Wuthering Heights to corpus
# 	Wuthering Heights successfully added to corpus
#
#
# Adding Moby Dick to corpus
# moby-dick_17
# moby-dick_28
# 	Moby Dick successfully added to corpus
#
#
# Adding Little Women to corpus
# 	Little Women successfully added to corpus
#
#
# BUILD COMPLETE
# WRITING TO FILE
# To access corpus contents, use BechdelCorpusObject.read_corpus()

# %%
reader = Bechdel.read_corpus()

# %%
import pandas as pd

books_df = pd.read_csv("corpus.csv")
books_df.head()
# Out:
#                  title  male_mentions           author  \
# 0            Moby Dick              0  Herman Melville
# 1            Moby Dick              0  Herman Melville
# 2  Pride and Prejudice              1      Jane Austen
# 3  Pride and Prejudice              6      Jane Austen
# 4            Moby Dick              0  Herman Melville
#
#                                                 text  male_speakers  \
# 0  \nLXXXIII\nJonah Historically Regarded\n\nRefe...             16
# 1  \nXCVII\nThe Lamp\n\nHad you descended from th...              0
# 2  \nI\nIt is a truth universally acknowledged, t...             12
# 3  \nXL\nElizabeth’s impatience to acquaint Jane ...             11
# 4  \nXL\nMidnight, Forecastle\n\nHarpooneers and ...              0
#
#    female_speakers  bechdel                      id
# 0                3    False            moby-dick_83
# 1                0    False            moby-dick_97
# 2                8    False   pride-and-prejudice_1
# 3               28    False  pride-and-prejudice_40
# 4                0    False            moby-dick_40

# %%
books_df['title'].unique().tolist()
# Out:
# ['Moby Dick',
#  'Pride and Prejudice',
#  'Sense and Sensibility',
#  'Wuthering Heights',
#  'Persuasion',
#  'Northanger Abbey',
#  'Emma',
#  'Mansfield Park',
#  'Little Women']

# %%
from collections import Counter
from nltk.corpus import stopwords

def get_book_stats(book_df):
    """
    Given a passed Pandas dataFrame object containing information about the book, this will calculate relevant statistics about the book.

    Parameters:
    ------
    `book_df`: Pandas dataFrame object
    """
    
    book_tokens = []

    for row in book_df.index:
        for word in book_df.loc[row, 'text'].split(" "):
            book_tokens.append(word)

    book_types = set(book_tokens)
    total_male_speakers = book_df['male_speakers'].sum()
    total_female_speakers = book_df['female_speakers'].sum()
    bechdel_passes = book_df['bechdel'].sum()
    book_title = book_df['title'].unique().tolist()[0]
    book_overall_pass = None

    counter = Counter(word.lower() for word in book_tokens)
    stopwords_set = stopwords.words("English")
    stopwords_set.extend(["would", "could", "one", "may"])

    if bechdel_passes > 0:
        book_overall_pass = "Yes"
    else:
        book_overall_pass = "No"

    print(f"\nBook title: {book_title}")
    print(f"Number of chapters that pass the Bechdel Test: {bechdel_passes}, {round(bechdel_passes / len(book_df) * 100, 2)}% of all chapters")
    print(f"Number of chapters that fail the Bechdel Test: {len(book_df) - bechdel_passes}, {round((len(book_df) - bechdel_passes) / len(book_df) * 100, 2)}% of all chapters")
    print(f"Book Bechdel Test evaluation: {book_overall_pass}")
    print(f"Most common words: {(' '.join([pair[0] for pair in counter.most_common(10)]))}")
    print(f"Most common words excluding stopwords: {(' '.join([pair[0] for pair in counter.most_common(500) if pair[0].isalpha() and pair[0].lower() not in stopwords_set][:10]))}")
    print(f"Total instaces of male speakers: {total_male_speakers}")
    print(f"Total instaces of female speakers: {total_female_speakers}")
    print(f"Total tokens: {len(book_tokens)}")
    print(f"Total types: {len(book_types)}\n")

# %%
list_of_dfs = []

moby_dick_df = books_df.query("title == 'Moby Dick'")
list_of_dfs.append(moby_dick_df)
p_and_p_df = books_df.query("title == 'Pride and Prejudice'")
list_of_dfs.append(p_and_p_df)
s_and_s_df = books_df.query("title == 'Sense and Sensibility'")
list_of_dfs.append(s_and_s_df)
w_heights_df = books_df.query("title == 'Wuthering Heights'")
list_of_dfs.append(w_heights_df)
persuasion_df = books_df.query("title == 'Persuasion'")
list_of_dfs.append(persuasion_df)
north_a_df = books_df.query("title == 'Northanger Abbey'")
list_of_dfs.append(north_a_df)
emma_df = books_df.query("title == 'Emma'")
list_of_dfs.append(emma_df)
mans_park_df = books_df.query("title == 'Mansfield Park'")
list_of_dfs.append(mans_park_df)
lil_wom_df = books_df.query("title == 'Little Women'")
list_of_dfs.append(lil_wom_df)

# %%
for book_df in list_of_dfs:
    get_book_stats(book_df)
# Out:
# Book title: Moby Dick
# Number of chapters that pass the Bechdel Test: 2, 1.48% of all chapters
# Number of chapters that fail the Bechdel Test: 133, 98.52% of all chapters
# Book Bechdel Test evaluation: Yes
# Most common words: the of and a to in that his it he
# Most common words excluding stopwords: like upon whale old though still great yet seemed must
# Total instaces of male speakers: 528
# Total instaces of female speakers: 104
# Total tokens: 202865
# Total types: 32626
#
#
# Book title: Pride and Prejudice
# Number of chapters that pass the Bechdel Test: 0, 0.0% of all chapters
# Number of chapters that fail the Bechdel Test: 61, 100.0% of all chapters
# Book Bechdel Test evaluation: No
# Most common words: the to of and a her in was i she
# Most common words excluding stopwords: said must elizabeth much miss never though soon might know
# Total instaces of male speakers: 1170
# Total instaces of female speakers: 2002
# Total tokens: 118383
# Total types: 13719
#
#
# Book title: Sense and Sensibility
# Number of chapters that pass the Bechdel Test: 2, 4.0% of all chapters
# Number of chapters that fail the Bechdel Test: 48, 96.0% of all chapters
# Book Bechdel Test evaluation: Yes
# Most common words: to the of and her a in was i she
# Most common words excluding stopwords: said must much every elinor might though marianne miss think
# Total instaces of male speakers: 972
# Total instaces of female speakers: 1860
# Total tokens: 116110
# Total types: 13692
#
#
# Book title: Wuthering Heights
# Number of chapters that pass the Bechdel Test: 0, 0.0% of all chapters
# Number of chapters that fail the Bechdel Test: 34, 100.0% of all chapters
# Book Bechdel Test evaluation: No
# Most common words: the and to i a of he his in you
# Most common words excluding stopwords: said shall must never little catherine see like till come
# Total instaces of male speakers: 955
# Total instaces of female speakers: 807
# Total tokens: 113444
# Total types: 18913
#
#
# Book title: Persuasion
# Number of chapters that pass the Bechdel Test: 0, 0.0% of all chapters
# Number of chapters that fail the Bechdel Test: 24, 100.0% of all chapters
# Book Bechdel Test evaluation: No
# Most common words: the to and of a in was had she her
# Most common words excluding stopwords: captain anne must much lady little might never good said
# Total instaces of male speakers: 926
# Total instaces of female speakers: 1270
# Total tokens: 81631
# Total types: 11237
#
#
# Book title: Northanger Abbey
# Number of chapters that pass the Bechdel Test: 1, 3.23% of all chapters
# Number of chapters that fail the Bechdel Test: 30, 96.77% of all chapters
# Book Bechdel Test evaluation: Yes
# Most common words: the of to and a her in was i she
# Most common words excluding stopwords: catherine miss must never much said might every think though
# Total instaces of male speakers: 567
# Total instaces of female speakers: 985
# Total tokens: 75573
# Total types: 11471
#
#
# Book title: Emma
# Number of chapters that pass the Bechdel Test: 0, 0.0% of all chapters
# Number of chapters that fail the Bechdel Test: 55, 100.0% of all chapters
# Book Bechdel Test evaluation: No
# Most common words: to the and of a i was she in not
# Most common words excluding stopwords: miss must much said emma little think never might quite
# Total instaces of male speakers: 2171
# Total instaces of female speakers: 2702
# Total tokens: 152637
# Total types: 18334
#
#
# Book title: Mansfield Park
# Number of chapters that pass the Bechdel Test: 0, 0.0% of all chapters
# Number of chapters that fail the Bechdel Test: 48, 100.0% of all chapters
# Book Bechdel Test evaluation: No
# Most common words: the to and of a her was in she i
# Most common words excluding stopwords: must much miss said fanny think might sir little never
# Total instaces of male speakers: 2211
# Total instaces of female speakers: 1943
# Total tokens: 156665
# Total types: 16724
#
#
# Book title: Little Women
# Number of chapters that pass the Bechdel Test: 0, 0.0% of all chapters
# Number of chapters that fail the Bechdel Test: 47, 100.0% of all chapters
# Book Bechdel Test evaluation: No
# Most common words: and the to a of her i in she for
# Most common words excluding stopwords: little said jo like never old meg amy good go
# Total instaces of male speakers: 2776
# Total instaces of female speakers: 4422
# Total tokens: 181120
# Total types: 23551
